# %%
import pandas as pd

# %%
# pandas behind the scene automatically import numpy/

#Series -------------------->

empty_series = pd.Series()

# %%
empty_series = pd.Series(data = None , dtype = 'int')

# %%
empty_series
# Out:
# Series([], dtype: int64)

# %%
type(empty_series)
# Out:
# pandas.core.series.Series

# %%
print(empty_series)
# Out:
# Series([], dtype: int64)

# %%
production_data = [1000, 1200, 1100, 950 , 1050, 1430, 1760]
production_day = ['Day1' , 'Day2' , 'Day3' , 'Day4' , 'Day5' , 'Day6' , 'Day7']

# %%
daily_production = pd.Series(data = production_data, index = production_day, name = 'Production_Details')

# %%
daily_production
# daily_production.name
# it has integer indices on top of it , it has labelled indices
# Out:
# Day1    1000
# Day2    1200
# Day3    1100
# Day4     950
# Day5    1050
# Day6    1430
# Day7    1760
# Name: Production_Details, dtype: int64

# %%
daily_production = pd.Series(data = production_data, index = production_day)
daily_production
# Out:
# Day1    1000
# Day2    1200
# Day3    1100
# Day4     950
# Day5    1050
# Day6    1430
# Day7    1760
# dtype: int64

# %%
# daily_production = pd.Series(data = production_data[1:], index = production_day)

# the index and the data must have length , ,index is also optional

# %%
daily_production = pd.Series(production_data)
daily_production
# Out:
# 0    1000
# 1    1200
# 2    1100
# 3     950
# 4    1050
# 5    1430
# 6    1760
# dtype: int64

# %%
daily_production = pd.Series(production_data , production_day)
daily_production
# Out:
# Day1    1000
# Day2    1200
# Day3    1100
# Day4     950
# Day5    1050
# Day6    1430
# Day7    1760
# dtype: int64

# %%
type(daily_production)
# Out:
# pandas.core.series.Series

# %%
daily_production.name  #no name is specified

# %%
daily_production.index
# Out:
# Index(['Day1', 'Day2', 'Day3', 'Day4', 'Day5', 'Day6', 'Day7'], dtype='object')

# %%
daily_production.values
# Out:
# array([1000, 1200, 1100,  950, 1050, 1430, 1760])

# %%
daily_production.dtype
# Out:
# dtype('int64')

# %%
daily_production.shape
# Out:
# (7,)

# %%
daily_production.ndim
# Out:
# 1

# %%
daily_production.size
# Out:
# 7

# %%
len(daily_production)
# Out:
# 7

# %%
daily_production.empty  #empty - flag
# Out:
# False

# %%
monthly_expenses = {'jan':1233.32,
                    'frb':2312,
                    'mar':1234,
                    'apr':765}
expenses_series = pd.Series(data = monthly_expenses)
expenses_series
# Out:
# jan    1233.32
# frb    2312.00
# mar    1234.00
# apr     765.00
# dtype: float64

# %%
monthly_expenses = {'jan':1233.32,
                    'frb':"343",
                    'mar':1234,
                    'apr':765}
expenses_series = pd.Series(data = monthly_expenses)
expenses_series

# the type of whole series is object but each element have diff data types
# Out:
# jan    1233.32
# frb        343
# mar       1234
# apr        765
# dtype: object

# %%
type(expenses_series['jan'])
# Out:
# float

# %%
type(expenses_series['frb'])
# Out:
# str

# %%
# Example 2----------------->

# %%
daily_production
# Out:
# Day1    1000
# Day2    1200
# Day3    1100
# Day4     950
# Day5    1050
# Day6    1430
# Day7    1760
# dtype: int64

# %%
daily_production.name

# %%
daily_production.rename(index = 'Daily_Prod')  #not an inplace operation
# Out:
# Day1    1000
# Day2    1200
# Day3    1100
# Day4     950
# Day5    1050
# Day6    1430
# Day7    1760
# Name: Daily_Prod, dtype: int64

# %%
daily_production.name

# %%
daily_production.rename(index = 'Daily_Prod' , inplace = True) #default of inplace is False
# Out:
# Day1    1000
# Day2    1200
# Day3    1100
# Day4     950
# Day5    1050
# Day6    1430
# Day7    1760
# Name: Daily_Prod, dtype: int64

# %%
daily_production.name
# Out:
# 'Daily_Prod'

# %%
daily_production = daily_production.rename(index = 'Prod_daily')
daily_production.name
# Out:
# 'Prod_daily'

# %%
daily_production.name = 'Daily_Production'
daily_production
# Out:
# Day1    1000
# Day2    1200
# Day3    1100
# Day4     950
# Day5    1050
# Day6    1430
# Day7    1760
# Name: Daily_Production, dtype: int64

# %%
daily_production.reset_index()
# Out:
#   index  Daily_Production
# 0  Day1              1000
# 1  Day2              1200
# 2  Day3              1100
# 3  Day4               950
# 4  Day5              1050
# 5  Day6              1430
# 6  Day7              1760

# %%
type(daily_production.reset_index())
# Out:
# pandas.core.frame.DataFrame

# %%
daily_production
# Out:
# Day1    1000
# Day2    1200
# Day3    1100
# Day4     950
# Day5    1050
# Day6    1430
# Day7    1760
# Name: Daily_Production, dtype: int64

# %%
daily_production.index
# Out:
# Index(['Day1', 'Day2', 'Day3', 'Day4', 'Day5', 'Day6', 'Day7'], dtype='object')

# %%
daily_production.reset_index(drop = True)
# Out:
# 0    1000
# 1    1200
# 2    1100
# 3     950
# 4    1050
# 5    1430
# 6    1760
# Name: Daily_Production, dtype: int64

# %%
type(daily_production.reset_index(drop = True))
# Out:
# pandas.core.series.Series

# %%
daily_production
# Out:
# Day1    1000
# Day2    1200
# Day3    1100
# Day4     950
# Day5    1050
# Day6    1430
# Day7    1760
# Name: Daily_Production, dtype: int64

# %%
daily_production.index
# Out:
# Index(['Day1', 'Day2', 'Day3', 'Day4', 'Day5', 'Day6', 'Day7'], dtype='object')

# %%
daily_production.reset_index(drop = True,inplace = True)

# %%
daily_production.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
daily_production
# Out:
# 0    1000
# 1    1200
# 2    1100
# 3     950
# 4    1050
# 5    1430
# 6    1760
# Name: Daily_Production, dtype: int64

# %%
daily_production.index = ['Mon' , 'tues', 'wed' , 'thrus' ,'Fri' , 'sat','sun']

# %%
daily_production
# Out:
# Mon      1000
# tues     1200
# wed      1100
# thrus     950
# Fri      1050
# sat      1430
# sun      1760
# Name: Daily_Production, dtype: int64

# %%
import numpy as np

# %%
employee_names = np.array(['aarti' , 'david' , 'mahommad' , 'pranjal'])
employee_ID = np.array([5645, 9767, 5324, 7686])

# %%
employee_series = pd.Series(employee_names , employee_ID)
employee_series
# Out:
# 5645       aarti
# 9767       david
# 5324    mahommad
# 7686     pranjal
# dtype: object

# %%
daily_production
# Out:
# Mon      1000
# tues     1200
# wed      1100
# thrus     950
# Fri      1050
# sat      1430
# sun      1760
# Name: Daily_Production, dtype: int64

# %%
daily_production>1000  #output: series
# Out:
# Mon      False
# tues      True
# wed       True
# thrus    False
# Fri       True
# sat       True
# sun       True
# Name: Daily_Production, dtype: bool

# %%
daily_production[daily_production>1000 ]
# Out:
# tues    1200
# wed     1100
# Fri     1050
# sat     1430
# sun     1760
# Name: Daily_Production, dtype: int64

# %%
daily_production<1500  #output: series
# Out:
# Mon       True
# tues      True
# wed       True
# thrus     True
# Fri       True
# sat       True
# sun      False
# Name: Daily_Production, dtype: bool

# %%
(daily_production>1000 ) & (daily_production<1500)
# Out:
# Mon      False
# tues      True
# wed       True
# thrus    False
# Fri       True
# sat       True
# sun      False
# Name: Daily_Production, dtype: bool

# %%
daily_production[(daily_production>1000 ) & (daily_production<1500)]
# Out:
# tues    1200
# wed     1100
# Fri     1050
# sat     1430
# Name: Daily_Production, dtype: int64

# %%
daily_production.max()
# Out:
# np.int64(1760)

# %%
daily_production.idxmax()
# Out:
# 'sun'

# %%
daily_production.min()
# Out:
# np.int64(950)

# %%
daily_production.idxmin()
# Out:
# 'thrus'

# %%
daily_production
# Out:
# Mon      1000
# tues     1200
# wed      1100
# thrus     950
# Fri      1050
# sat      1430
# sun      1760
# Name: Daily_Production, dtype: int64

# %%
daily_production.sort_values()
# Out:
# thrus     950
# Mon      1000
# Fri      1050
# wed      1100
# tues     1200
# sat      1430
# sun      1760
# Name: Daily_Production, dtype: int64

# %%
daily_production
# Out:
# Mon      1000
# tues     1200
# wed      1100
# thrus     950
# Fri      1050
# sat      1430
# sun      1760
# Name: Daily_Production, dtype: int64

# %%
daily_production.sort_values(ascending = False)
# Out:
# sun      1760
# sat      1430
# tues     1200
# wed      1100
# Fri      1050
# Mon      1000
# thrus     950
# Name: Daily_Production, dtype: int64

# %%
daily_production
# Out:
# Mon      1000
# tues     1200
# wed      1100
# thrus     950
# Fri      1050
# sat      1430
# sun      1760
# Name: Daily_Production, dtype: int64

# %%
daily_production.sort_values(ascending = False , inplace = True)

# %%
daily_production
# Out:
# sun      1760
# sat      1430
# tues     1200
# wed      1100
# Fri      1050
# Mon      1000
# thrus     950
# Name: Daily_Production, dtype: int64

# %%
daily_production.sum()
# Out:
# np.int64(8490)

# %%
daily_production.mean()
# Out:
# np.float64(1212.857142857143)

# %%
series_1 = pd.Series(data = [287, 343 , 187] , index = ['Asif' , 'Bhairavi', 'chad'] , name = 'Monday')
series_2 = pd.Series(data = [186 , 524, 202] , index = ['Asif' , 'Bhairavi', 'chad'] , name = 'Tuesday')

# %%
series_1
# Out:
# Asif        287
# Bhairavi    343
# chad        187
# Name: Monday, dtype: int64

# %%
series_2
# Out:
# Asif        186
# Bhairavi    524
# chad        202
# Name: Tuesday, dtype: int64

# %%
series_1+series_2
# Out:
# Asif        473
# Bhairavi    867
# chad        389
# dtype: int64

# %%
series_1.add(series_2)
# Out:
# Asif        473
# Bhairavi    867
# chad        389
# dtype: int64

# %%
series_2.add(series_1)
# Out:
# Asif        473
# Bhairavi    867
# chad        389
# dtype: int64

# %%
series_1 = pd.Series(data = [287, 343 , 187] , index = ['Asif' , 'Bhairavi', 'chad'] , name = 'Monday')
series_2 = pd.Series(data = [186 , 524, 202] , index = ['Asif' , 'Bhairavi', 'colin'] , name = 'Tuesday')

# %%
series_1
# Out:
# Asif        287
# Bhairavi    343
# chad        187
# Name: Monday, dtype: int64

# %%
series_2
# Out:
# Asif        186
# Bhairavi    524
# colin       202
# Name: Tuesday, dtype: int64

# %%
series_1+series_2
# Out:
# Asif        473.0
# Bhairavi    867.0
# chad          NaN
# colin         NaN
# dtype: float64

# %%
#Quiz 1 ------------->
# which customer had maximum bill
cust_names = ['chad' , 'Farheen' , 'Mimadri' , 'Monisha']
cust_bill = [256.78 , 434.53 , 109.25 , 529.42]
cust_info = pd.Series(cust_bill , cust_names)
cust_info.idxmax()
# Out:
# 'Monisha'

# %%
#Quiz_2

#which customer has crossed prepaid balance?
cust_names = ['chad' , 'Farheen' , 'Mimadri' , 'Monisha']
cust_bill = [256.78 , 434.53 , 109.25 , 529.42]
cust_info = pd.Series(cust_bill , cust_names)
cust_paid = [500, 1000, 750 , 500]

# %%
cust_paid = [500 , 1000, 750 , 500]
prepaid_balance = pd.Series(cust_paid , cust_names)
crossed_balance = cust_info > prepaid_balance
crossed_customers = crossed_balance[crossed_balance]
print("Customers who crossed their prepaid balance:", crossed_customers)
# if only string is needed than use actual address
crossed_customers.index[0]
# Out:
# Customers who crossed their prepaid balance: Monisha    True
# dtype: bool
# 'Monisha'

# %%
# Dataframes ------------->

# Example 1 ------------->
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.empty
# Out:
# True

# %%
cust_data = [['001' , 'Alice' , 'alice@example.com' , '123-456-7890', 20],
             ['002' , 'Bhooshan' , 'bob@exapmle.com', '987-654-3210' , 15],
             ['003' , 'Carl' , 'charlie@example.com' , '555-123-4567' , 25]]

cust_cols = ['CustomerID' , 'Name' , 'Email' , 'Phone' , 'TotalPurchase']
df = pd.DataFrame(data = cust_data , columns = cust_cols)

# %%
df
# Out:
#   CustomerID      Name                Email         Phone  TotalPurchase
# 0        001     Alice    alice@example.com  123-456-7890             20
# 1        002  Bhooshan      bob@exapmle.com  987-654-3210             15
# 2        003      Carl  charlie@example.com  555-123-4567             25

# %%
cust_data = [['001' , 'Alice' , 'alice@example.com' , '123-456-7890', 20],
             ['002' , 'Bhooshan' , 'bob@exapmle.com', '987-654-3210' , 15],
             ['003' , 'Carl' , 'charlie@example.com' , '555-123-4567' , 25]]

cust_cols = ['CustomerID' , 'Name' , 'Email' , 'Phone' , 'TotalPurchase']
# cust_id = ['A', 'B', 'C']
df = pd.DataFrame(data = cust_data , columns = cust_cols) #, index = cust_id)

#index = row ; data = columns data ; columns = columns name

# %%
df
# Out:
#   CustomerID      Name                Email         Phone  TotalPurchase
# 0        001     Alice    alice@example.com  123-456-7890             20
# 1        002  Bhooshan      bob@exapmle.com  987-654-3210             15
# 2        003      Carl  charlie@example.com  555-123-4567             25

# %%
cust_data = [['001' , 'Alice' , 'alice@example.com' , '123-456-7890', 20],
             ['002' , 'Bhooshan' , 'bob@exapmle.com', '987-654-3210' , 15],
             ['003' , 'Carl' , 'charlie@example.com' , 25]]  #pandas doesnt know that 25 is not a phone number

cust_cols = ['CustomerID' , 'Name' , 'Email' , 'Phone' , 'TotalPurchase']
# cust_id = ['A', 'B', 'C']
df = pd.DataFrame(data = cust_data , columns = cust_cols) 
df
# Out:
#   CustomerID      Name                Email         Phone  TotalPurchase
# 0        001     Alice    alice@example.com  123-456-7890           20.0
# 1        002  Bhooshan      bob@exapmle.com  987-654-3210           15.0
# 2        003      Carl  charlie@example.com            25            NaN

# %%
#pandas is not able to create a dataframe if the length of the columns is not equal to the length of the data points.
# ideally it is better if the length of each onservation and the number of columns are matching
# to avoid any interpretation issues

cust_data = {'CustomerID ': ['001' , '002' , '003'],
            'Name' : ['alice' , 'charlie' , 'david'],
            'Phone' : ['alice@gmail.com' , 'charlie.gmail.com' , 'david@gmail.com'],
            'TotalPurchase' : [20 , 15 , 25 ]}

cust_index = ['001' , '002' , '003' ]
df = pd.DataFrame(data = cust_data , index = cust_index)
df
# Out:
#     CustomerID      Name              Phone  TotalPurchase
# 001         001    alice    alice@gmail.com             20
# 002         002  charlie  charlie.gmail.com             15
# 003         003    david    david@gmail.com             25

# %%
#directly also we can do this
cust_data = {'CustomerID ': ['001' , '002' , '003'],
            'Name' : ['alice' , 'charlie' , 'david'],
            'Phone' : ['alice@gmail.com' , 'charlie.gmail.com' , 'david@gmail.com'],
            'TotalPurchase' : [20 , 15 , 25 ]}

df = pd.DataFrame(cust_data)
df
# Out:
#   CustomerID      Name              Phone  TotalPurchase
# 0         001    alice    alice@gmail.com             20
# 1         002  charlie  charlie.gmail.com             15
# 2         003    david    david@gmail.com             25

# %%
#Example 2 ------------>

# Reading data into dataframes
df = pd.read_csv(r'Buffet_Details (1).csv')

# %%
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df = pd.read_csv(filepath_or_buffer = 'Buffet_Details (1).csv' , index_col = 'Name')
#Name has became a index

# %%
df
# Out:
#          Room  Age   Cuisine  Expenditure
# Name
# Shilpa     A1   18    Indian        24.65
# Jaspreet   A2   32  American        18.54
# Dominic    A3   19    Indian        27.66
# Ahmad      A4   22  American        19.54
# Joseph     A5   28    Indian        17.32
# Saju       A6   31    Indian        12.56
# Monica     A7   48   Chinese        11.09
# Preeti     A8   67  American        12.23
# Emma       A9   24    Indian        18.88
# Gaurav    A10   29   Chinese        14.43

# %%
# df = pd.read_excel(io = 'Buffet_Details (1).xlsx' , index_col = 'Room')
df
# Out:
#          Room  Age   Cuisine  Expenditure
# Name
# Shilpa     A1   18    Indian        24.65
# Jaspreet   A2   32  American        18.54
# Dominic    A3   19    Indian        27.66
# Ahmad      A4   22  American        19.54
# Joseph     A5   28    Indian        17.32
# Saju       A6   31    Indian        12.56
# Monica     A7   48   Chinese        11.09
# Preeti     A8   67  American        12.23
# Emma       A9   24    Indian        18.88
# Gaurav    A10   29   Chinese        14.43

# %%
#Quiz_1

# Load the file carprices.csv ito a dataframe df_cars and study it. Don't specify the index columns
df_cars = pd.read_csv('carprice.csv')

# %%
df_cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 194         -1                95        volvo       gas        std
# 195         -1                95        volvo       gas      turbo
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo    diesel      turbo
# 198         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
#Quiz_2

# load movie ratings into dataframes df_movies and specify the index column as the user_id

df_movies = pd.read_csv(filepath_or_buffer = 'movie_ratings.csv' )#, index_col = 'rating' )
df_movies 

#i m not able to make column
# Out:
#    movie_id   user_id   rating
# 0       196       242        3
# 1       186       302        3
# 2        22       377        1
# 3       244        51        2
# 4       166       346        1

# %%
# Example 3 ------->

# studying dataframes----->
df
# Out:
#          Room  Age   Cuisine  Expenditure
# Name
# Shilpa     A1   18    Indian        24.65
# Jaspreet   A2   32  American        18.54
# Dominic    A3   19    Indian        27.66
# Ahmad      A4   22  American        19.54
# Joseph     A5   28    Indian        17.32
# Saju       A6   31    Indian        12.56
# Monica     A7   48   Chinese        11.09
# Preeti     A8   67  American        12.23
# Emma       A9   24    Indian        18.88
# Gaurav    A10   29   Chinese        14.43

# %%
df.head() #it gives me the first 5 elements of the dataset
# Out:
#          Room  Age   Cuisine  Expenditure
# Name
# Shilpa     A1   18    Indian        24.65
# Jaspreet   A2   32  American        18.54
# Dominic    A3   19    Indian        27.66
# Ahmad      A4   22  American        19.54
# Joseph     A5   28    Indian        17.32

# %%
df.head(n=3) #first 3
# Out:
#          Room  Age   Cuisine  Expenditure
# Name
# Shilpa     A1   18    Indian        24.65
# Jaspreet   A2   32  American        18.54
# Dominic    A3   19    Indian        27.66

# %%
df.tail() #bottom 5
# Out:
#        Room  Age   Cuisine  Expenditure
# Name
# Saju     A6   31    Indian        12.56
# Monica   A7   48   Chinese        11.09
# Preeti   A8   67  American        12.23
# Emma     A9   24    Indian        18.88
# Gaurav  A10   29   Chinese        14.43

# %%
df.tail(n=3) #bottom 3
# Out:
#        Room  Age   Cuisine  Expenditure
# Name
# Preeti   A8   67  American        12.23
# Emma     A9   24    Indian        18.88
# Gaurav  A10   29   Chinese        14.43

# %%
df.axes  #it gives columns & rows
# Out:
# [Index(['Shilpa', 'Jaspreet', 'Dominic', 'Ahmad', 'Joseph', 'Saju', 'Monica',
#         'Preeti', 'Emma', 'Gaurav'],
#        dtype='object', name='Name'),
#  Index(['Room', 'Age', 'Cuisine', 'Expenditure'], dtype='object')]

# %%
df.index   #it will give row index (index attributes of the dataframe
# Out:
# Index(['Shilpa', 'Jaspreet', 'Dominic', 'Ahmad', 'Joseph', 'Saju', 'Monica',
#        'Preeti', 'Emma', 'Gaurav'],
#       dtype='object', name='Name')

# %%
len(df)
# Out:
# 10

# %%
df.columns
# Out:
# Index(['Room', 'Age', 'Cuisine', 'Expenditure'], dtype='object')

# %%
df.shape
# Out:
# (10, 4)

# %%
df.size
# Out:
# 40

# %%
df.dtypes
# Out:
# Room            object
# Age              int64
# Cuisine         object
# Expenditure    float64
# dtype: object

# %%
df.info() #its a command
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Shilpa to Gaurav
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Room         10 non-null     object
#  1   Age          10 non-null     int64
#  2   Cuisine      10 non-null     object
#  3   Expenditure  10 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df.keys()  #columns
# Out:
# Index(['Room', 'Age', 'Cuisine', 'Expenditure'], dtype='object')

# %%
df.values #rows data
# Out:
# array([['A1', 18, 'Indian', 24.65],
#        ['A2', 32, 'American', 18.54],
#        ['A3', 19, 'Indian', 27.66],
#        ['A4', 22, 'American', 19.54],
#        ['A5', 28, 'Indian', 17.32],
#        ['A6', 31, 'Indian', 12.56],
#        ['A7', 48, 'Chinese', 11.09],
#        ['A8', 67, 'American', 12.23],
#        ['A9', 24, 'Indian', 18.88],
#        ['A10', 29, 'Chinese', 14.43]], dtype=object)

# %%
tempdf = pd.read_csv('Buffet_Details (1).csv' , index_col = 'Room')

# %%
tempdf
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32
# A6        Saju   31    Indian        12.56
# A7      Monica   48   Chinese        11.09
# A8      Preeti   67  American        12.23
# A9        Emma   24    Indian        18.88
# A10     Gaurav   29   Chinese        14.43

# %%
tempdf.head()
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32

# %%
tempdf.shape  #10 , 4 because room is a index
# Out:
# (10, 4)

# %%
tempdf.columns  #columns
# Out:
# Index(['Name', 'Age', 'Cuisine', 'Expenditure'], dtype='object')

# %%
tempdf.index  #rows name
# Out:
# Index(['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10'], dtype='object', name='Room')

# %%
tempdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, A1 to A10
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         10 non-null     object
#  1   Age          10 non-null     int64
#  2   Cuisine      10 non-null     object
#  3   Expenditure  10 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df = pd.read_csv('Buffet_Details (1).csv')
df.transpose() #it do transpose all rows to columns
# Out:
#                   0         1        2         3       4       5        6  \
# Room             A1        A2       A3        A4      A5      A6       A7
# Name         Shilpa  Jaspreet  Dominic     Ahmad  Joseph    Saju   Monica
# Age              18        32       19        22      28      31       48
# Cuisine      Indian  American   Indian  American  Indian  Indian  Chinese
# Expenditure   24.65     18.54    27.66     19.54   17.32   12.56    11.09
#
#                     7       8        9
# Room               A8      A9      A10
# Name           Preeti    Emma   Gaurav
# Age                67      24       29
# Cuisine      American  Indian  Chinese
# Expenditure     12.23   18.88    14.43

# %%
df.transpose().dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# 7    object
# 8    object
# 9    object
# dtype: object

# %%
tempdf
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32
# A6        Saju   31    Indian        12.56
# A7      Monica   48   Chinese        11.09
# A8      Preeti   67  American        12.23
# A9        Emma   24    Indian        18.88
# A10     Gaurav   29   Chinese        14.43

# %%
tempdf.transpose()
# Out:
# Room             A1        A2       A3        A4      A5      A6       A7  \
# Name         Shilpa  Jaspreet  Dominic     Ahmad  Joseph    Saju   Monica
# Age              18        32       19        22      28      31       48
# Cuisine      Indian  American   Indian  American  Indian  Indian  Chinese
# Expenditure   24.65     18.54    27.66     19.54   17.32   12.56    11.09
#
# Room               A8      A9      A10
# Name           Preeti    Emma   Gaurav
# Age                67      24       29
# Cuisine      American  Indian  Chinese
# Expenditure     12.23   18.88    14.43

# %%
#Quiz_3 
#Print top four observations in the df_cars dataframes

df_car = pd.read_csv('carprice.csv')
df_car.head(4)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# ...

# %%
#Quiz_4
# print bottom six observation from car
df_car.tail(6)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 193         -1                74  volvo       gas      turbo         four
# 194         -1                95  volvo       gas        std         four
# 195         -1                95  volvo       gas      turbo         four
# 196         -1                95  volvo       gas        std         four
# 197         -1                95  volvo    diesel      turbo         four
# 198         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 193      wagon          rwd           front       104.3  ...          130
# 194      sedan          rwd           front       109.1  ...          141
# 195      sedan          rwd           front       109.1  ...          141
# 196      sedan          rwd           front       109.1  ...          173
# 197      sedan          rwd           front       109.1  ...          145
# ...

# %%
df_cars.shape
# Out:
# (199, 26)

# %%
df_cars.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm               int64
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#Accessing Data from the Dataframes----------------->

# Example 1 -------->
# Direct Access-->

df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df.Room
# Out:
# 0     A1
# 1     A2
# 2     A3
# 3     A4
# 4     A5
# 5     A6
# 6     A7
# 7     A8
# 8     A9
# 9    A10
# Name: Room, dtype: object

# %%
type(df.Room)
# Out:
# pandas.core.series.Series

# %%
df['Age']
# Out:
# 0    18
# 1    32
# 2    19
# 3    22
# 4    28
# 5    31
# 6    48
# 7    67
# 8    24
# 9    29
# Name: Age, dtype: int64

# %%
df[['Age']]  #Dataframe with one column
# Out:
#    Age
# 0   18
# 1   32
# 2   19
# 3   22
# 4   28
# 5   31
# 6   48
# 7   67
# 8   24
# 9   29

# %%
df[['Cuisine' , 'Age']]  #it should be a list , and access it with another column
# Out:
#     Cuisine  Age
# 0    Indian   18
# 1  American   32
# 2    Indian   19
# 3  American   22
# 4    Indian   28
# 5    Indian   31
# 6   Chinese   48
# 7  American   67
# 8    Indian   24
# 9   Chinese   29

# %%
df['Cuisine']
# Out:
# 0      Indian
# 1    American
# 2      Indian
# 3    American
# 4      Indian
# 5      Indian
# 6     Chinese
# 7    American
# 8      Indian
# 9     Chinese
# Name: Cuisine, dtype: object

# %%
df['Cuisine'][0]  #if we give '0' it will be key error
# Out:
# 'Indian'

# %%
tempdf
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32
# A6        Saju   31    Indian        12.56
# A7      Monica   48   Chinese        11.09
# A8      Preeti   67  American        12.23
# A9        Emma   24    Indian        18.88
# A10     Gaurav   29   Chinese        14.43

# %%
tempdf['Expenditure']
# Out:
# Room
# A1     24.65
# A2     18.54
# A3     27.66
# A4     19.54
# A5     17.32
# A6     12.56
# A7     11.09
# A8     12.23
# A9     18.88
# A10    14.43
# Name: Expenditure, dtype: float64

# %%
tempdf['Expenditure'][0]  #integer indexing
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14392\2117823858.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tempdf['Expenditure'][0]  #integer indexing
# np.float64(24.65)

# %%
tempdf['Expenditure']['A1']  #Label indexing will also work
# Out:
# np.float64(24.65)

# %%
#Quiz_7
# access the car name frame df_cars

df_cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 194         -1                95        volvo       gas        std
# 195         -1                95        volvo       gas      turbo
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo    diesel      turbo
# 198         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_cars[['price']]
# Out:
#      price
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# ..     ...
# 194  16845
# 195  19045
# 196  21485
# 197  22470
# 198  22625
#
# [199 rows x 1 columns]

# %%
df_cars.price
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 194    16845
# 195    19045
# 196    21485
# 197    22470
# 198    22625
# Name: price, Length: 199, dtype: object

# %%
#Quiz_8
# access the ratings of some movie from df_movies
df_movies
# Out:
#    movie_id   user_id   rating
# 0       196       242        3
# 1       186       302        3
# 2        22       377        1
# 3       244        51        2
# 4       166       346        1

# %%
df_cars[['bore' , 'stroke']]
# Out:
#      bore  stroke
# 0    3.47    2.68
# 1    3.47    2.68
# 2    2.68    3.47
# 3    3.19    3.40
# 4    3.19    3.40
# ..    ...     ...
# 194  3.78    3.15
# 195  3.78    3.15
# 196  3.58    2.87
# 197  3.01    3.40
# 198  3.78    3.15
#
# [199 rows x 2 columns]

# %%
# Example 2------------->

# the loc indexer-----> loc = location

df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
tempdf
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32
# A6        Saju   31    Indian        12.56
# A7      Monica   48   Chinese        11.09
# A8      Preeti   67  American        12.23
# A9        Emma   24    Indian        18.88
# A10     Gaurav   29   Chinese        14.43

# %%
df.loc[0]  #i got first observation it gives me the series.
# Out:
# Room               A1
# Name           Shilpa
# Age                18
# Cuisine        Indian
# Expenditure     24.65
# Name: 0, dtype: object

# %%
tempdf.loc['A1']
# Out:
# Name           Shilpa
# Age                18
# Cuisine        Indian
# Expenditure     24.65
# Name: A1, dtype: object

# %%
df.loc[: , 'Age']#: all the rows
# Out:
# 0    18
# 1    32
# 2    19
# 3    22
# 4    28
# 5    31
# 6    48
# 7    67
# 8    24
# 9    29
# Name: Age, dtype: int64

# %%
df.loc[: , 'Age'][1]
# Out:
# np.int64(32)

# %%
df.loc[1,'Age']
# Out:
# np.int64(32)

# %%
tempdf
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32
# A6        Saju   31    Indian        12.56
# A7      Monica   48   Chinese        11.09
# A8      Preeti   67  American        12.23
# A9        Emma   24    Indian        18.88
# A10     Gaurav   29   Chinese        14.43

# %%
tempdf.loc['A1', 'Age']
# Out:
# np.int64(18)

# %%
df.loc[0,['Age' , 'Expenditure']]
# Out:
# Age               18
# Expenditure    24.65
# Name: 0, dtype: object

# %%
tempdf.loc[['A1', 'A7'], ['Age' , 'Expenditure']]  #rows a1 , a7  && columns Age and Expenditure
# Out:
#       Age  Expenditure
# Room
# A1     18        24.65
# A7     48        11.09

# %%
tempdf.loc['A2':'A6' , ['Age','Expenditure']]
# Out:
#       Age  Expenditure
# Room
# A2     32        18.54
# A3     19        27.66
# A4     22        19.54
# A5     28        17.32
# A6     31        12.56

# %%
tempdf.loc['A2':'A6' , 'Age':'Expenditure']
# Out:
#       Age   Cuisine  Expenditure
# Room
# A2     32  American        18.54
# A3     19    Indian        27.66
# A4     22  American        19.54
# A5     28    Indian        17.32
# A6     31    Indian        12.56

# %%
tempdf.loc['A4':, :'Cuisine']
# Out:
#         Name  Age   Cuisine
# Room
# A4     Ahmad   22  American
# A5    Joseph   28    Indian
# A6      Saju   31    Indian
# A7    Monica   48   Chinese
# A8    Preeti   67  American
# A9      Emma   24    Indian
# A10   Gaurav   29   Chinese

# %%
#Quiz_10
# which car's information is stored in the 78th row of the df_cars df?
df_cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 194         -1                95        volvo       gas        std
# 195         -1                95        volvo       gas      turbo
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo    diesel      turbo
# 198         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_cars.loc[3].make
# Out:
# 'audi'

# %%
#Quiz_11

# what is the make of wheel-base = 99.8?
df_cars.loc[: ,['wheel-base' , 'make']]
# df_cars.loc[3]
# Out:
#      wheel-base         make
# 0          88.6  alfa-romero
# 1          88.6  alfa-romero
# 2          94.5  alfa-romero
# 3          99.8         audi
# 4          99.4         audi
# ..          ...          ...
# 194       109.1        volvo
# 195       109.1        volvo
# 196       109.1        volvo
# 197       109.1        volvo
# 198       109.1        volvo
#
# [199 rows x 2 columns]

# %%
import pandas as pd

# %%
#Example_3 -------------->
#The iloc indexer--->
df = pd.read_csv('Buffet_Details (1).csv')

# %%
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
tempdf = pd.read_csv(filepath_or_buffer = 'Buffet_Details (1).csv' , index_col = 'Room')

# %%
tempdf
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32
# A6        Saju   31    Indian        12.56
# A7      Monica   48   Chinese        11.09
# A8      Preeti   67  American        12.23
# A9        Emma   24    Indian        18.88
# A10     Gaurav   29   Chinese        14.43

# %%
df_cars = pd.read_csv('carprice.csv')

# %%
df_cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 194         -1                95        volvo       gas        std
# 195         -1                95        volvo       gas      turbo
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo    diesel      turbo
# 198         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
tempdf
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32
# A6        Saju   31    Indian        12.56
# A7      Monica   48   Chinese        11.09
# A8      Preeti   67  American        12.23
# A9        Emma   24    Indian        18.88
# A10     Gaurav   29   Chinese        14.43

# %%
df.loc[0]
# Out:
# Room               A1
# Name           Shilpa
# Age                18
# Cuisine        Indian
# Expenditure     24.65
# Name: 0, dtype: object

# %%
df.iloc[0]   #it access only integers
# Out:
# Room               A1
# Name           Shilpa
# Age                18
# Cuisine        Indian
# Expenditure     24.65
# Name: 0, dtype: object

# %%
tempdf.loc['A1']
# Out:
# Name           Shilpa
# Age                18
# Cuisine        Indian
# Expenditure     24.65
# Name: A1, dtype: object

# %%
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df.iloc[0,1]
# Out:
# 'Shilpa'

# %%
tempdf
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32
# A6        Saju   31    Indian        12.56
# A7      Monica   48   Chinese        11.09
# A8      Preeti   67  American        12.23
# A9        Emma   24    Indian        18.88
# A10     Gaurav   29   Chinese        14.43

# %%
tempdf.iloc[0,1]  #integer indexing
# Out:
# np.int64(18)

# %%
df.iloc[0:5, 1]  #rows from 0 to 4 and 1 column
# Out:
# 0      Shilpa
# 1    Jaspreet
# 2     Dominic
# 3       Ahmad
# 4      Joseph
# Name: Name, dtype: object

# %%
df.iloc[0:5 , 1:3]
# Out:
#        Name  Age
# 0    Shilpa   18
# 1  Jaspreet   32
# 2   Dominic   19
# 3     Ahmad   22
# 4    Joseph   28

# %%
df.iloc[[0,2,7] , [0,2,3]]  #column number 0 , 2 & 7 ,,, rows 0 , 2, 3
# Out:
#   Room  Age   Cuisine
# 0   A1   18    Indian
# 2   A3   19    Indian
# 7   A8   67  American

# %%
#Quiz_13
df_cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 194         -1                95        volvo       gas        std
# 195         -1                95        volvo       gas      turbo
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo    diesel      turbo
# 198         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_cars.iloc[77 , 2]
# Out:
# 'mitsubishi'

# %%
#Example 4 ---------------->
df
# #The at and iat indexes--->
df.at[3 , 'Expenditure']
# Out:
# np.float64(19.54)

# %%
tempdf.at['A3' , 'Cuisine']
# Out:
# 'Indian'

# %%
df.iat[2,3]
# Out:
# 'Indian'

# %%
tempdf.iat[4, 3]
# Out:
# np.float64(17.32)

# %%
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df.dtypes
# Out:
# Room            object
# Name            object
# Age              int64
# Cuisine         object
# Expenditure    float64
# dtype: object

# %%
df.select_dtypes(include = object)
# Out:
#   Room      Name   Cuisine
# 0   A1    Shilpa    Indian
# 1   A2  Jaspreet  American
# 2   A3   Dominic    Indian
# 3   A4     Ahmad  American
# 4   A5    Joseph    Indian
# 5   A6      Saju    Indian
# 6   A7    Monica   Chinese
# 7   A8    Preeti  American
# 8   A9      Emma    Indian
# 9  A10    Gaurav   Chinese

# %%
df.select_dtypes(int)
# Out:
#    Age
# 0   18
# 1   32
# 2   19
# 3   22
# 4   28
# 5   31
# 6   48
# 7   67
# 8   24
# 9   29

# %%
df.select_dtypes(float)
# Out:
#    Expenditure
# 0        24.65
# 1        18.54
# 2        27.66
# 3        19.54
# 4        17.32
# 5        12.56
# 6        11.09
# 7        12.23
# 8        18.88
# 9        14.43

# %%
#Example 6------------------->

#Accessing data conditionally,also called Boolean indexing

df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df['Expenditure']>15  #whwre is my expend >15?
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# 9    False
# Name: Expenditure, dtype: bool

# %%
df[df['Expenditure']>15]  #it gives me subset of dataframe where this condition is true
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 8   A9      Emma   24    Indian        18.88

# %%
df['Expenditure'][df['Expenditure']>15] #only accessing that part of the expenditure
# Out:
# 0    24.65
# 1    18.54
# 2    27.66
# 3    19.54
# 4    17.32
# 8    18.88
# Name: Expenditure, dtype: float64

# %%
df[['Expenditure','Room']][df['Expenditure']>15]
# Out:
#    Expenditure Room
# 0        24.65   A1
# 1        18.54   A2
# 2        27.66   A3
# 3        19.54   A4
# 4        17.32   A5
# 8        18.88   A9

# %%
df['Cuisine'] == 'Indian'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# Name: Cuisine, dtype: bool

# %%
(df['Expenditure']>15) & (df['Cuisine'] == 'Indian')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
df[(df['Expenditure']>15) & (df['Cuisine'] == 'Indian')]
# Out:
#   Room     Name  Age Cuisine  Expenditure
# 0   A1   Shilpa   18  Indian        24.65
# 2   A3  Dominic   19  Indian        27.66
# 4   A5   Joseph   28  Indian        17.32
# 8   A9     Emma   24  Indian        18.88

# %%
df[(df['Expenditure']>15) & (df['Cuisine'] == 'Indian')]['Room'] 
#Rooms who are spending more money on indian food
# Out:
# 0    A1
# 2    A3
# 4    A5
# 8    A9
# Name: Room, dtype: object

# %%
df['Room']
# Out:
# 0     A1
# 1     A2
# 2     A3
# 3     A4
# 4     A5
# 5     A6
# 6     A7
# 7     A8
# 8     A9
# 9    A10
# Name: Room, dtype: object

# %%
(df['Expenditure']>15) & (df['Cuisine'] == 'Indian')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
df['Room'][(df['Expenditure']>15) & (df['Cuisine'] == 'Indian')]
# Out:
# 0    A1
# 2    A3
# 4    A5
# 8    A9
# Name: Room, dtype: object

# %%
tempdf[tempdf['Expenditure']>15]
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32
# A9        Emma   24    Indian        18.88

# %%
df['Room'][(df['Expenditure']>15) | (df['Cuisine'] == 'Indian')]
# Out:
# 0    A1
# 1    A2
# 2    A3
# 3    A4
# 4    A5
# 5    A6
# 8    A9
# Name: Room, dtype: object

# %%
df['Cuisine'].isin(['Indian' , 'Chinese']) #whose cuisine is indian or chinese
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# 9     True
# Name: Cuisine, dtype: bool

# %%
(df['Cuisine']=='Indian') | (df['Cuisine'] == 'Chinese')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# 9     True
# Name: Cuisine, dtype: bool

# %%
~df['Cuisine'].isin(['Indian' , 'Chinese'])  #~ is compliment
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: Cuisine, dtype: bool

# %%
#Quiz_16 ---------------->

#How many cars in the df_cars dataframe are sedans?

# df_cars[df_cars['carbody'] == 'sedan']
# len(df_cars[df_cars['carbody'] == 'sedan'])

# %%
#Quiz_17 ------------------->

# len(df_movies[(df_movies['Thor']>7) & (df_movies['Spiderman']>7)])

# %%
#Quiz_18 ---------------------->

# len(df_cars[(df_cars['city_mileage']>20) & (df_cars['price']<15000) & (df_cars['type']=='Convertible')])

# %%
#Dataframe Operations---------------->

#Example 1--------------------->
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df.dtypes
# Out:
# Room            object
# Name            object
# Age              int64
# Cuisine         object
# Expenditure    float64
# dtype: object

# %%
df['Expenditure'].astype('int')  #changing type
# Out:
# 0    24
# 1    18
# 2    27
# 3    19
# 4    17
# 5    12
# 6    11
# 7    12
# 8    18
# 9    14
# Name: Expenditure, dtype: int64

# %%
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df['Age'].astype(str)[0]
# Out:
# '18'

# %%
df.dtypes
# Out:
# Room            object
# Name            object
# Age              int64
# Cuisine         object
# Expenditure    float64
# dtype: object

# %%
dfnew = df.convert_dtypes() #it convert the coloumns to suitble type

# %%
dfnew.dtypes
# Out:
# Room           string[python]
# Name           string[python]
# Age                     Int64
# Cuisine        string[python]
# Expenditure           Float64
# dtype: object

# %%
#Example 2

# Arithmetic and inter-column operations

df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df['Expenditure']+10
# Out:
# 0    34.65
# 1    28.54
# 2    37.66
# 3    29.54
# 4    27.32
# 5    22.56
# 6    21.09
# 7    22.23
# 8    28.88
# 9    24.43
# Name: Expenditure, dtype: float64

# %%
df['Expenditure']-5
# Out:
# 0    19.65
# 1    13.54
# 2    22.66
# 3    14.54
# 4    12.32
# 5     7.56
# 6     6.09
# 7     7.23
# 8    13.88
# 9     9.43
# Name: Expenditure, dtype: float64

# %%
df['Expenditure']*2
# Out:
# 0    49.30
# 1    37.08
# 2    55.32
# 3    39.08
# 4    34.64
# 5    25.12
# 6    22.18
# 7    24.46
# 8    37.76
# 9    28.86
# Name: Expenditure, dtype: float64

# %%
df['Expenditure']/3
# Out:
# 0    8.216667
# 1    6.180000
# 2    9.220000
# 3    6.513333
# 4    5.773333
# 5    4.186667
# 6    3.696667
# 7    4.076667
# 8    6.293333
# 9    4.810000
# Name: Expenditure, dtype: float64

# %%
df['Age'] + 10
# Out:
# 0    28
# 1    42
# 2    29
# 3    32
# 4    38
# 5    41
# 6    58
# 7    77
# 8    34
# 9    39
# Name: Age, dtype: int64

# %%
df['Expenditure'].add(5)  #doesnot have an inplace parameter
# Out:
# 0    29.65
# 1    23.54
# 2    32.66
# 3    24.54
# 4    22.32
# 5    17.56
# 6    16.09
# 7    17.23
# 8    23.88
# 9    19.43
# Name: Expenditure, dtype: float64

# %%
df['Expenditure']+df['Age']
# Out:
# 0    42.65
# 1    50.54
# 2    46.66
# 3    41.54
# 4    45.32
# 5    43.56
# 6    59.09
# 7    79.23
# 8    42.88
# 9    43.43
# dtype: float64

# %%
df['Name'] +df['Cuisine']
# Out:
# 0        ShilpaIndian
# 1    JaspreetAmerican
# 2       DominicIndian
# 3       AhmadAmerican
# 4        JosephIndian
# 5          SajuIndian
# 6       MonicaChinese
# 7      PreetiAmerican
# 8          EmmaIndian
# 9       GauravChinese
# dtype: object

# %%
df.round()  #it knows on which datatype it has to round of the value
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian         25.0
# 1   A2  Jaspreet   32  American         19.0
# 2   A3   Dominic   19    Indian         28.0
# 3   A4     Ahmad   22  American         20.0
# 4   A5    Joseph   28    Indian         17.0
# 5   A6      Saju   31    Indian         13.0
# 6   A7    Monica   48   Chinese         11.0
# 7   A8    Preeti   67  American         12.0
# 8   A9      Emma   24    Indian         19.0
# 9  A10    Gaurav   29   Chinese         14.0

# %%
df['Expenditure'].round()
# Out:
# 0    25.0
# 1    19.0
# 2    28.0
# 3    20.0
# 4    17.0
# 5    13.0
# 6    11.0
# 7    12.0
# 8    19.0
# 9    14.0
# Name: Expenditure, dtype: float64

# %%
#Quiz_1 -------------------->

# Find the mean of the bore and the stroke of each car in the df_cars dataframe.
# Add this value as a new column to the existing dataframe with the feature name 'avgmpg' .
# Print the subset of the dataframes with the car name, city mileage , highway mileage, and average milage.

df_cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 194         -1                95        volvo       gas        std
# 195         -1                95        volvo       gas      turbo
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo    diesel      turbo
# 198         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_cars['avgpmg'] = (df_cars['bore']+df_cars['stroke'])/2

# %%
df_cars.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'avgpmg'],
#       dtype='object')

# %%
df_cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 194         -1                95        volvo       gas        std
# 195         -1                95        volvo       gas      turbo
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo    diesel      turbo
# 198         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
#Quiz_3

# Each car inthe df_cars dataframes also has spatial dimensions associated with it , namely 'symboling'
# 'horsepower' , 'city-mpg', 'bore'. Asssuming that the cars are the cars are all cuboidal in shape, calculate the density of each car. 
# store this new feature in the original dtaframe named alpmc.

# %%
df_cars[['symboling' , 'horsepower' , 'city-mpg' , 'bore']]
# Out:
#      symboling  horsepower  city-mpg  bore
# 0            3         111        21  3.47
# 1            3         111        21  3.47
# 2            1         154        19  2.68
# 3            2         102        24  3.19
# 4            2         115        18  3.19
# ..         ...         ...       ...   ...
# 194         -1         114        23  3.78
# 195         -1         160        19  3.78
# 196         -1         134        18  3.58
# 197         -1         106        26  3.01
# 198         -1         114        19  3.78
#
# [199 rows x 4 columns]

# %%
df_cars['alpmc'] = (df_cars['symboling']*(df_cars['horsepower']+df_cars['city-mpg'])/df_cars['bore'])

# %%
df_cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 194         -1                95        volvo       gas        std
# 195         -1                95        volvo       gas      turbo
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo    diesel      turbo
# 198         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
#Example_3

#Statistical operations

df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df['Age'].sum()
# Out:
# np.int64(318)

# %%
df['Age'].mean()
# Out:
# np.float64(31.8)

# %%
df['Expenditure'].mean()
# Out:
# np.float64(17.69)

# %%
tempdf
# Out:
#           Name  Age   Cuisine  Expenditure
# Room
# A1      Shilpa   18    Indian        24.65
# A2    Jaspreet   32  American        18.54
# A3     Dominic   19    Indian        27.66
# A4       Ahmad   22  American        19.54
# A5      Joseph   28    Indian        17.32
# A6        Saju   31    Indian        12.56
# A7      Monica   48   Chinese        11.09
# A8      Preeti   67  American        12.23
# A9        Emma   24    Indian        18.88
# A10     Gaurav   29   Chinese        14.43

# %%
tempdf['Age']
# Out:
# Room
# A1     18
# A2     32
# A3     19
# A4     22
# A5     28
# A6     31
# A7     48
# A8     67
# A9     24
# A10    29
# Name: Age, dtype: int64

# %%
tempdf['Age'].mean()
# Out:
# np.float64(31.8)

# %%
df['Age'].max()
# Out:
# np.int64(67)

# %%
df['Age'].min()
# Out:
# np.int64(18)

# %%
df['Age'].idxmin()  #index of minimum value
# Out:
# 0

# %%
tempdf['Age'].idxmin()
# Out:
# 'A1'

# %%
df['Expenditure'].idxmin()
# Out:
# 6

# %%
df['Expenditure'].median()
# Out:
# np.float64(17.93)

# %%
df.describe()  #it tells the numeric of the database
# Out:
#              Age  Expenditure
# count  10.000000    10.000000
# mean   31.800000    17.690000
# std    15.039208     5.414554
# min    18.000000    11.090000
# 25%    22.500000    13.027500
# 50%    28.500000    17.930000
# 75%    31.750000    19.375000
# max    67.000000    27.660000

# %%
df.describe().transpose()
# Out:
#              count   mean        std    min      25%    50%     75%    max
# Age           10.0  31.80  15.039208  18.00  22.5000  28.50  31.750  67.00
# Expenditure   10.0  17.69   5.414554  11.09  13.0275  17.93  19.375  27.66

# %%
df['Cuisine'].unique() # array
# Out:
# array(['Indian', 'American', 'Chinese'], dtype=object)

# %%
df['Cuisine'].value_counts()  #number of unique   #series
# Out:
# Cuisine
# Indian      5
# American    3
# Chinese     2
# Name: count, dtype: int64

# %%
df['Cuisine'].mode()
# Out:
# 0    Indian
# Name: Cuisine, dtype: object

# %%
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df['Age'].mean()
# Out:
# np.float64(31.8)

# %%
df['Age'].aggregate('mean')
# Out:
# np.float64(31.8)

# %%
df[['Age' , 'Expenditure']].aggregate('mean')
# Out:
# Age            31.80
# Expenditure    17.69
# dtype: float64

# %%
df.aggregate({'Age': 'median' , 'Expenditure' : 'mean'})
# Out:
# Age            28.50
# Expenditure    17.69
# dtype: float64

# %%
#Quiz_5 
# price diffrence between most & least expensive car
# df_cars.info()

# df_cars['curb-weight'] = df_cars['curb-weight'].astype(int)
df_cars['curb-weight'].max() - df_cars['curb-weight'].min()
# Out:
# np.int64(2578)

# %%
df_cars.loc[df_cars['curb-weight'].idxmax()]  #idxmax gives loc index
# Out:
# symboling                 0
# normalized-losses       145
# make                 jaguar
# fuel-type               gas
# aspiration              std
# num-of-doors           four
# body-style            sedan
# drive-wheels            rwd
# engine-location       front
# wheel-base            113.0
# length                199.6
# width                  69.6
# height                 52.8
# curb-weight            4066
# engine-type            dohc
# num-of-cylinders        six
# engine-size             258
# fuel-system            mpfi
# bore                   3.63
# stroke                 4.17
# compression-ratio       8.1
# horsepower              176
# peak-rpm               4750
# city-mpg                 15
# highway-mpg              19
# price                 32250
# avgpmg                  3.9
# alpmc                   0.0
# Name: 47, dtype: object

# %%
#Quiz_7 --------------->
#Number of cars with two doors or four doors?--->

df_cars['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    113
# two      84
# ?         2
# Name: count, dtype: int64

# %%
len(df_cars[df_cars['num-of-doors'] == 'four'])
# Out:
# 113

# %%
len(df_cars[df_cars['num-of-doors'] == 'two'])
# Out:
# 84

# %%
# df_cars.mean(axis = 1)  #rows wise
# df_cars.mean(axis = 0) # column wise

# %%
temptempdf = df.sort_values(by = 'Expenditure')  #sorted by ascending order
temptempdf
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 5   A6      Saju   31    Indian        12.56
# 9  A10    Gaurav   29   Chinese        14.43
# 4   A5    Joseph   28    Indian        17.32
# 1   A2  Jaspreet   32  American        18.54
# 8   A9      Emma   24    Indian        18.88
# 3   A4     Ahmad   22  American        19.54
# 0   A1    Shilpa   18    Indian        24.65
# 2   A3   Dominic   19    Indian        27.66

# %%
temptempdf.loc[6]
# Out:
# Room                A7
# Name            Monica
# Age                 48
# Cuisine        Chinese
# Expenditure      11.09
# Name: 6, dtype: object

# %%
temptempdf.iloc[0]
# Out:
# Room                A7
# Name            Monica
# Age                 48
# Cuisine        Chinese
# Expenditure      11.09
# Name: 6, dtype: object

# %%
df.sort_values(by = 'Expenditure' , ascending = False)
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 2   A3   Dominic   19    Indian        27.66
# 0   A1    Shilpa   18    Indian        24.65
# 3   A4     Ahmad   22  American        19.54
# 8   A9      Emma   24    Indian        18.88
# 1   A2  Jaspreet   32  American        18.54
# 4   A5    Joseph   28    Indian        17.32
# 9  A10    Gaurav   29   Chinese        14.43
# 5   A6      Saju   31    Indian        12.56
# 7   A8    Preeti   67  American        12.23
# 6   A7    Monica   48   Chinese        11.09

# %%
df.sort_values(by = ['Cuisine', 'Expenditure'])

# it basically sorted the cuisine alphabetically and within that sorted cuisine
# it sorted expenditure
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 7   A8    Preeti   67  American        12.23
# 1   A2  Jaspreet   32  American        18.54
# 3   A4     Ahmad   22  American        19.54
# 6   A7    Monica   48   Chinese        11.09
# 9  A10    Gaurav   29   Chinese        14.43
# 5   A6      Saju   31    Indian        12.56
# 4   A5    Joseph   28    Indian        17.32
# 8   A9      Emma   24    Indian        18.88
# 0   A1    Shilpa   18    Indian        24.65
# 2   A3   Dominic   19    Indian        27.66

# %%
df.sort_index()
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df.sort_index(ascending = False)
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 9  A10    Gaurav   29   Chinese        14.43
# 8   A9      Emma   24    Indian        18.88
# 7   A8    Preeti   67  American        12.23
# 6   A7    Monica   48   Chinese        11.09
# 5   A6      Saju   31    Indian        12.56
# 4   A5    Joseph   28    Indian        17.32
# 3   A4     Ahmad   22  American        19.54
# 2   A3   Dominic   19    Indian        27.66
# 1   A2  Jaspreet   32  American        18.54
# 0   A1    Shilpa   18    Indian        24.65

# %%
#Example_5 ------------------------>
# Function ----------------->

# %%
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df.round()
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian         25.0
# 1   A2  Jaspreet   32  American         19.0
# 2   A3   Dominic   19    Indian         28.0
# 3   A4     Ahmad   22  American         20.0
# 4   A5    Joseph   28    Indian         17.0
# 5   A6      Saju   31    Indian         13.0
# 6   A7    Monica   48   Chinese         11.0
# 7   A8    Preeti   67  American         12.0
# 8   A9      Emma   24    Indian         19.0
# 9  A10    Gaurav   29   Chinese         14.0

# %%
import numpy as np
df.apply(np.round)   #i can apply numpy function from apply
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian         25.0
# 1   A2  Jaspreet   32  American         19.0
# 2   A3   Dominic   19    Indian         28.0
# 3   A4     Ahmad   22  American         20.0
# 4   A5    Joseph   28    Indian         17.0
# 5   A6      Saju   31    Indian         13.0
# 6   A7    Monica   48   Chinese         11.0
# 7   A8    Preeti   67  American         12.0
# 8   A9      Emma   24    Indian         19.0
# 9  A10    Gaurav   29   Chinese         14.0

# %%
df['Expenditure'].apply(np.round)
# Out:
# 0    25.0
# 1    19.0
# 2    28.0
# 3    20.0
# 4    17.0
# 5    13.0
# 6    11.0
# 7    12.0
# 8    19.0
# 9    14.0
# Name: Expenditure, dtype: float64

# %%
#The apply method helps in defining functions that can be applied on the elements of datafrmaes
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
def first_three(row):  #assuming row is a string
    row = row[:3]
    return row

# %%
df['Name'].apply(first_three)
# Out:
# 0    Shi
# 1    Jas
# 2    Dom
# 3    Ahm
# 4    Jos
# 5    Saj
# 6    Mon
# 7    Pre
# 8    Emm
# 9    Gau
# Name: Name, dtype: object

# %%
df[['Name', 'Cuisine']].apply(first_three)
# Out:
#        Name   Cuisine
# 0    Shilpa    Indian
# 1  Jaspreet  American
# 2   Dominic    Indian

# %%
df[['Name', 'Cuisine']].applymap(first_three) #this applies correctly to the two columns
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14392\1750935348.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[['Name', 'Cuisine']].applymap(first_three) #this applies correctly to the two columns
#   Name Cuisine
# 0  Shi     Ind
# 1  Jas     Ame
# 2  Dom     Ind
# 3  Ahm     Ame
# 4  Jos     Ind
# 5  Saj     Ind
# 6  Mon     Chi
# 7  Pre     Ame
# 8  Emm     Ind
# 9  Gau     Chi

# %%
df['Cuisine'].apply(lambda x: 1 if x == 'Indian' else 0)
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# 5    1
# 6    0
# 7    0
# 8    1
# 9    0
# Name: Cuisine, dtype: int64

# %%
#Example_6

#Groupby ---------------->
df
# Out:
#   Room      Name  Age   Cuisine  Expenditure
# 0   A1    Shilpa   18    Indian        24.65
# 1   A2  Jaspreet   32  American        18.54
# 2   A3   Dominic   19    Indian        27.66
# 3   A4     Ahmad   22  American        19.54
# 4   A5    Joseph   28    Indian        17.32
# 5   A6      Saju   31    Indian        12.56
# 6   A7    Monica   48   Chinese        11.09
# 7   A8    Preeti   67  American        12.23
# 8   A9      Emma   24    Indian        18.88
# 9  A10    Gaurav   29   Chinese        14.43

# %%
df.groupby(by = 'Cuisine')

# %%
df.groupby(by = 'Cuisine').mean(numeric_only = True)
# Out:
#                 Age  Expenditure
# Cuisine
# American  40.333333       16.770
# Chinese   38.500000       12.760
# Indian    24.000000       20.214

# %%
df.groupby(by = 'Cuisine')['Expenditure']

# %%
df.groupby(by = 'Cuisine')['Expenditure'].mean()
# Out:
# Cuisine
# American    16.770
# Chinese     12.760
# Indian      20.214
# Name: Expenditure, dtype: float64

# %%
df.groupby(by = 'Cuisine')['Expenditure'].apply(np.mean)
# Out:
# Cuisine
# American    16.770
# Chinese     12.760
# Indian      20.214
# Name: Expenditure, dtype: float64

# %%
df.groupby(by = 'Cuisine')[['Expenditure', 'Age']].mean()
# Out:
#           Expenditure        Age
# Cuisine
# American       16.770  40.333333
# Chinese        12.760  38.500000
# Indian         20.214  24.000000

# %%
#groupby + aggregate--------->

grouped_df = df.groupby('Cuisine')
summary_df = grouped_df.aggregate({'Expenditure':'mean'})
summary_df
# Out:
#           Expenditure
# Cuisine
# American       16.770
# Chinese        12.760
# Indian         20.214

# %%
grouped_df = df.groupby('Cuisine')
summary_df = grouped_df.aggregate({'Expenditure':'mean', 'Age':'mean'})
summary_df
# Out:
#           Expenditure        Age
# Cuisine
# American       16.770  40.333333
# Chinese        12.760  38.500000
# Indian         20.214  24.000000

# %%
grouped_df = df.groupby('Cuisine')
summary_df = grouped_df.aggregate({'Expenditure':'mean', 'Age':'median'})
summary_df
# Out:
#           Expenditure   Age
# Cuisine
# American       16.770  32.0
# Chinese        12.760  38.5
# Indian         20.214  24.0

# %%
grouped_df = df.groupby('Cuisine')
summary_df = grouped_df.aggregate({'Expenditure':'sum', 'Age' : 'mean'})
summary_df
# Out:
#           Expenditure        Age
# Cuisine
# American        50.31  40.333333
# Chinese         25.52  38.500000
# Indian         101.07  24.000000
